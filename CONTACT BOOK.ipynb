# %% [markdown]
# #  CONTACT BOOK USING PYTHON  #
#
# SUBJECT    : PYTHON PROGRAMMING
#
# Degree     : B.Tech
#
# Department : Information Technology
#
# Topic      : CONTACT BOOK
#
# College    : PSG College of Tecnology
#
#
# TEAM MEMBERS:       Rollno:
#
# 1.P.K.GOKULNATH    (19I217)  -->(Coding,Comments)
#
# 2.HARISH           (19I223)  --->(Coding,Comments)
#
# 3.SAI CHARAN       (19I214)  --->(some Comments)
#
#
# ABOUT THIS PROJECT:
#
# Contact Management System  is created in Python. The data has a python script (index.py).
# In the course of building your program one of the first things that gets created is the contacts.txt file.
# If this file doesn’t exist though, as is the case when the program is run for the very first time, Python will stop
# execution of the program, and indicate that fact as an error.
# Speaking about the system, it consists of all the called for functions that include adding, viewing, removing and also     upgrading contact lists.
# While including the call of a person, he/she has to provide given name, address and contact information.
#
# PROGRAM SPECIFICATION:
#
# Program that has functions to:
# a. add an entry into a "list of lists" called contacts (add_contact function).
# b. write the contacts data to the "contacts.txt" data file before quitting the program.
# c. view all the information in contacts (view_all_contacts function).
# d. open the "contacts.txt" data file and place them into the contacts list (the initialize
# function)
# e. let the user to search for a name in contacts, and then prints out that person's information
# (find_contact function)
# f. let the user delete an entry (delete_contact function)
#
# Each line of "contacts.txt" will contain the record for a single person, with data fields on that line
# separated by the delimiter "\t" (Tab), as shown
#
# BACKGROUND
# One strategy for keeping track of data, even when a program isn’t running, is by storing it in a database, an
# external file. The simplest type of database is a “flat-file” database, in which information is stored as
# strings of text.
# In the example contacts.txt file shown below, each of the three lines is a “record” of one person, and
# each section of a line (separated by a “delimiter”, a tab in this case) stores a data “field”: names, email
# address, and phone number. The information in this text file will be loaded in to the program.
# when that program is run, and a menu system will run the contact information as
# the user desires.

# %%
import os
def initialize():
    # Specify handle for file and open for Reading
    infile = open("contacts.txt","r")
    
    # Initialize the contacts list to nothing
    contactsLines = []
    
    # Get one line at a time, and strip off newline
    for line in infile:
        contactsLines.append(line.rstrip("\n"))
    
    # Now we've got all the data, at least as lines
    infile.close()
    
    # Break lines up according to tab separators
    contacts = []
    for line in contactsLines:
        # split line up by tab separators and append it to our contacts list 
        contacts.append(line.split("\t"))
    return contacts

                           
        #This function is called by option 1 on the main menu, and allows the user to add their contacts.
def add_contact(contacts):
        print("Adding a contact")
        name = input("Contact name (First,last): ")  
        email = input("Contact email: ")            
        phone = input("Contact phone #: ")
        address = input("Contact address: ")
        new_contact = [name,email,phone,address]# Place fields in a list
        contacts.append(new_contact)# Append that list to contacts
    
def view_contacts(contacts):
    #This function is called by option 2 on the main menu, and allows the user to see all their contacts.
    if (len(contacts)!=0):
        for record in contacts:
            for field in record:
                print(field)
            print("-----")
    else:
        print("Contact book is Empty")
        
def find_contact(myContacts,required_contact):
        #This function is called by option 3 on the main menu, and allows the user to see the particular contact detail(list form) .
        k=0
        for record in myContacts:
            for field in record:
                if field == required_contact:
                    print(record)
                    print("-----")
                else:
                    k=1
        if k==1:                                     #if there is no match found then it prints not found
            print("Contact not found")

def delete_contact(myContacts,required_contact):
    #This function is called by option 4 on the main menu, and allows the user to delete the specific contact."""
    for record in myContacts:
        if required_contact in record:
            record.clear()
            print("Contact is deleted sucessfully")
            print("-----")               #as per the code while execution it only shows the empty list consists of symbol"-".

def write_file(contacts):
    # outfile is the "handle" that refers to the external file
    outfile = open("contacts.txt", "w")# "w" specifies that we're Writing to the file
    for record in contacts:          # go through the contacts...# Write to outfile a line for each contact
        outfile.write("\t".join(record)+"\n")
    outfile.close()                                # close the external file
    

def menu():
    print("+---------------------------+")
    print("|    ADDRESS BOOK           |")
    print("|                           |")
    print("| 1. Add contact            |")
    print("| 2. View contacts          |")
    print("| 3. Find specific contact  |")
    print("| 4. Delete specific contact|")
    print("| 5. clear all contacts     |")
    print("| 6. Exit                   |")
    print("+---------------------------+")
    
    choice = input("Enter your choice: ")    #Input is based on users choice
    return choice

def main():                                # main function starts here and depending on the user input functions are called 
    myContacts = initialize()              #open the "contacts.txt" data file and place them into the contacts list
    choice = ""
    while (choice !="6"):
        choice = menu()
        if choice == "1":
            add_contact(myContacts)
        elif choice == "2":
            view_contacts(myContacts)
        elif choice == "3":
            required_contact = input("Enter the contact name: ")
            find_contact(myContacts,required_contact)
        elif choice == "4":
            required_contact = input("Enter the contact to be deleted: ")
            delete_contact(myContacts,required_contact)
        elif choice=="5":
            myContacts.clear()                              #".clear()" it removes all the data stored in the list spontaneously.
            print("All the contacts cleared sucessfully\nEnter New contacts")
            print("-----")
    write_file(myContacts)
    print("Program closing")
if __name__ == "__main__":
    main()
# Out:
# +---------------------------+
# |    ADDRESS BOOK           |
# |                           |
# | 1. Add contact            |
# | 2. View contacts          |
# | 3. Find specific contact  |
# | 4. Delete specific contact|
# | 5. clear all contacts     |
# | 6. Exit                   |
# +---------------------------+
# Enter your choice: 3
# Enter the contact name: df
# Contact not found
# +---------------------------+
# |    ADDRESS BOOK           |
# |                           |
# | 1. Add contact            |
# | 2. View contacts          |
# | 3. Find specific contact  |
# | 4. Delete specific contact|
# | 5. clear all contacts     |
# | 6. Exit                   |
# +---------------------------+
# Enter your choice: 4
# Enter the contact to be deleted: jv
# Required data is deleted sucessfully
# -----
# +---------------------------+
# |    ADDRESS BOOK           |
# |                           |
# | 1. Add contact            |
# | 2. View contacts          |
# ...

# %% [markdown]
# # In the course of building the program one of the first things that gets created is the contacts.txt file.
# If this file doesn’t exist though, as is the case when the program is run for the very first time, Python will stop
# execution of the program, and indicate that fact as an error.
